# %% [markdown]
# # Amazon SageMaker モニタリング Part3(モデルドリフトとFeature Attribution)
#
# このノートブックを実行する時のヒント：
#
# - KernelはPython3（Data Science）で動作確認をしています。
# - デフォルトではSageMakerのデフォルトBucketを利用します。必要に応じて変更することも可能です。
# - 実際に動かさなくても出力を確認できるようにセルのアウトプットを残しています。きれいな状態から実行したい場合は、右クリックメニューから "Clear All Outputs"を選択して出力をクリアしてから始めてください。
# - 作成されたスケジュールはSageMaker StudioのSageMaker resource （左側ペインの一番下）のEndpointメニューからも確認可能です。
#
# ## 前提
# ### 使用するデータの背景
# 米国国勢調査局の 人口動態調査（Current Population Survey: CPS）- 社会経済年次補助（Annual Social and Economic Supplement: ASEC）を利用します。 CPS は、一般の労働者を含むグループの収入やその他の特性に関する月次の調査です。 また、年次社会経済補足（CPS-ASEC） は、毎年2月、3月、4月に実施され、15歳以上の人の労働経験、収入、非現金給付、移住に関する情報を提供しています。
#
# https://health.gov/healthypeople/objectives-and-data/data-sources-and-methods/data-sources/current-population-survey-annual-social-and-economic-supplement-cps-asec
#
# ### データ項目
# - A_AGE: 年齢(数値)
# - A_FTLF: 現在、フルタイムか(カテゴリ)
# - A_HGA: 学歴(カテゴリ)
# - A_HSCOL: 現在、高校/大学で就学しているか(カテゴリ)
# - A_MARITL: 婚姻状況(カテゴリ)
# - A_SEX: 性別(カテゴリ)
# - A_UNMEM: 労働組合員か(カテゴリ)
# - A_USLHRS: 労働時間(数値)
# - NOEMP: 雇用主の企業総従業員数(カテゴリ)
# - PENATVTY: 出身国(カテゴリ)
# - PRCITSHP: 市民権の記録(カテゴリ)
# - SEOTR: 自営業か(カテゴリ)
# - WKSWORK: 何週間働いたか(数値)
# - PTOTVAL: 総収入額(数値)、推論対象
#
# ### 運用時の課題
# 50000ドル以上の収入が得られる状況は年々変化することが想定される。また、学習時に重視していた特徴量が重要でなくなるなどの環境の変化も想定される。これらをモニタリングして、学習データの見直し、学習アルゴリズムの見直し、再学習を自動で行えるようにしたい。
#
# ### データ加工
# 1. 18歳以上のデータに限定
# 2. PTOTVALが50000ドル以上であれば1、そうでなければ0(変数名はPTOTVAL_Over50000)

# %% [markdown]
# ## ステップ0: モニタリング前の準備
# ### 環境準備

# %%
import boto3
import copy
import json
import os
import random
import requests
import time
import numpy as np
import pandas as pd

from datetime import datetime, timedelta

from sagemaker import get_execution_role, image_uris, Session
from sagemaker.clarify import (
    BiasConfig,
    DataConfig,
    ModelConfig,
    ModelPredictedLabelConfig,
    SHAPConfig,
)
from sagemaker.estimator import Estimator
from sagemaker.image_uris import retrieve
from sagemaker.inputs import TrainingInput
from sagemaker.model import Model
from sagemaker.model_monitor import (
    BiasAnalysisConfig,
    CronExpressionGenerator,
    DataCaptureConfig,
    EndpointInput,
    ExplainabilityAnalysisConfig,
    ModelBiasMonitor,
    ModelExplainabilityMonitor,
)
from sagemaker.s3 import S3Downloader, S3Uploader
from sagemaker.utils import name_from_base

# %%
role = get_execution_role()
print(f"RoleArn: {role}")

sagemaker_session = Session()
sagemaker_client = sagemaker_session.sagemaker_client
sagemaker_runtime_client = sagemaker_session.sagemaker_runtime_client

region = sagemaker_session.boto_region_name
print(f"AWS region: {region}")

bucket = Session().default_bucket()
print(f"Bucket: {bucket}")
prefix = "sagemaker/blackbelt-part3-sample"
s3_key = f"s3://{bucket}/{prefix}"
print(f"S3 key: {s3_key}")

s3_capture_upload_path = f"{s3_key}/datacapture"
ground_truth_upload_path = f"{s3_key}/ground_truth_data/{datetime.now():%Y-%m-%d-%H-%M-%S}"
s3_report_path = f"{s3_key}/reports"

print(f"Capture path: {s3_capture_upload_path}")
print(f"Ground truth path: {ground_truth_upload_path}")
print(f"Report path: {s3_report_path}")

baseline_prefix = 'baselining/baseline'
baseline_results_uri = f"{s3_key}/baselining"
print(f"Baseline results uri: {baseline_results_uri}")

endpoint_name = name_from_base(f"bb-example-xgboost-classification-model-")
print(f'Endpoint name: {endpoint_name}')
endpoint_instance_count = 1
endpoint_instance_type = "ml.m5.large"
schedule_expression = CronExpressionGenerator.hourly()

training_data_prefix = 'sample_data'
training_dataset_uri = f"{s3_key}/{training_data_prefix}"
print(f'Training dataset s3 path: {training_dataset_uri}')
training_instance_type = "ml.m5.xlarge"
# Out:
# RoleArn: arn:aws:iam::036661559124:role/service-role/AmazonSageMaker-ExecutionRole-20220417T231709
# AWS region: ap-northeast-1
# Bucket: sagemaker-ap-northeast-1-036661559124
# S3 key: s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample
# Capture path: s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/datacapture
# Ground truth path: s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/ground_truth_data/2023-01-04-12-11-59
# Report path: s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/reports
# Baseline results uri: s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/baselining
# Endpoint name: bb-example-xgboost-classification-model-2023-01-04-12-11-59-829
# Training dataset s3 path: s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/sample_data

# %% [markdown]
# ### データ準備
# 米国国勢調査局のデータをダウンロードします。

# %%
def get_csv_file(year):
    if year in [2019, 2020, 2021, 2022]:
        url = f"https://api.census.gov/data/{year}/cps/asec/mar?get=A_AGE,A_FTLF,A_HGA,A_HSCOL,A_MARITL,A_SEX,A_UNMEM,A_USLHRS,NOEMP,PENATVTY,PRCITSHP,SEOTR,WKSWORK,PTOTVAL"
    else:
        url = ""

    try:
        print(f"Downloading {year} file...")
        response = requests.request("GET", url, timeout=(3.0, 3600)).json()
        df = pd.DataFrame(response[1:], columns=response[0])
        df.to_csv(f'cps_{year}.csv')
    except json.JSONDecodeError:
        pass
    
def get_multi_records(years_list):
    for year in years_list:
        get_csv_file(year)

# %%
years = [2019, 2020, 2021, 2022]
get_multi_records(years)
# Out:
# Downloading 2019 file...
# Downloading 2020 file...
# Downloading 2021 file...
# Downloading 2022 file...

# %% [markdown]
# ### データ加工
# 18歳以上のデータを抽出し、年収が50000ドル以上かどうかのフラグ変数を作成します。加工後のデータをS3へアップロードします。

# %%
def data_processing(csv_name):
    df = pd.read_csv(csv_name, index_col=0)
    df = df[df['A_AGE'] >= 18]
    df['PTOTVAL_Over50000'] = np.select([df['PTOTVAL']>50000], [1], default=0)
    df = df.drop(['PTOTVAL'], axis=1)
    col_list = ['PTOTVAL_Over50000'] + df.columns.tolist()[:-1]
    df = df[col_list]
    
    return df

# %%
cps_2019_df = data_processing('cps_2019.csv')
cps_2019_df.to_csv("train.csv", header=False, index=False)
cps_2020_df = data_processing('cps_2020.csv')
cps_2020_df.to_csv("validation.csv", header=False, index=False)

boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(f'{prefix}/{training_data_prefix}', 'train/data.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(f'{prefix}/{training_data_prefix}', 'validation/data.csv')).upload_file('validation.csv')

train_input = TrainingInput(f'{training_dataset_uri}/train/data.csv', content_type="csv")
validation_input = TrainingInput(f'{training_dataset_uri}/validation/data.csv', content_type="csv")

# %% [markdown]
# ベースラインの作成に必要なデータを作成し、S3へアップロードします。またヘッダー情報を取得します。

# %%
baseline_file = 'baseline_with_header.csv'
baseline_dataset = cps_2020_df.sample(n=1000)
baseline_dataset.to_csv(baseline_file, header=True, index=False)
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(f'{prefix}/{baseline_prefix}', baseline_file)).upload_file(baseline_file)
baseline_uri = f'{s3_key}/{baseline_prefix}/{baseline_file}'
print(f'baseline_uri: {baseline_uri}')
# Out:
# baseline_uri: s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/baselining/baseline/baseline_with_header.csv

# %%
with open('baseline_with_header.csv') as f:
    headers_line = f.readline().rstrip()
all_headers = headers_line.split(",")
label_header = all_headers[0]

# %% [markdown]
# ### モデル準備
# ビルトインアルゴリズムのXGBoostを使用してモデルを作成します。

# %%
container = retrieve("xgboost", region, version="1.5-1")
xgb = Estimator(
    container,
    role,
    instance_count=1,
    instance_type=training_instance_type,
    disable_profiler=True,
    sagemaker_session=sagemaker_session,
)

xgb.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    objective="binary:logistic",
    num_round=800,
)

xgb.fit({'train': train_input, 'validation': validation_input})
# Out:
# 2023-01-04 12:14:15 Starting - Starting the training job...
# 2023-01-04 12:14:29 Starting - Preparing the instances for training............
# 2023-01-04 12:16:40 Downloading - Downloading input data
# 2023-01-04 12:16:40 Training - Training image download completed. Training in progress..[2023-01-04 12:16:41.892 ip-10-0-203-120.ap-northeast-1.compute.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2023-01-04:12:16:41:INFO] Imported framework sagemaker_xgboost_container.training
# [2023-01-04:12:16:41:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2023-01-04:12:16:41:INFO] No GPUs detected (normal if no gpus installed)
# [2023-01-04:12:16:41:INFO] Running XGBoost Sagemaker in algorithm mode
# [2023-01-04:12:16:41:INFO] Determined delimiter of CSV input is ','
# [2023-01-04:12:16:41:INFO] Determined delimiter of CSV input is ','
# [2023-01-04:12:16:41:INFO] files path: /opt/ml/input/data/train
# [2023-01-04:12:16:41:INFO] Determined delimiter of CSV input is ','
# [2023-01-04:12:16:42:INFO] files path: /opt/ml/input/data/validation
# [2023-01-04:12:16:42:INFO] Determined delimiter of CSV input is ','
# [2023-01-04:12:16:42:INFO] Single node training.
# [2023-01-04:12:16:42:INFO] Train matrix has 132868 rows and 13 columns
# [2023-01-04:12:16:42:INFO] Validation matrix has 117763 rows
# [2023-01-04 12:16:42.082 ip-10-0-203-120.ap-northeast-1.compute.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [12:16:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]#011train-logloss:0.61257#011validation-logloss:0.61642
# [1]#011train-logloss:0.55789#011validation-logloss:0.56494
# [2]#011train-logloss:0.51880#011validation-logloss:0.52843
# [3]#011train-logloss:0.49021#011validation-logloss:0.50201
# [4]#011train-logloss:0.46840#011validation-logloss:0.48225
# [5]#011train-logloss:0.45182#011validation-logloss:0.46709
# [6]#011train-logloss:0.43852#011validation-logloss:0.45499
# [7]#011train-logloss:0.42843#011validation-logloss:0.44599
# [8]#011train-logloss:0.42050#011validation-logloss:0.43904
# [9]#011train-logloss:0.41425#011validation-logloss:0.43351
# [10]#011train-logloss:0.40904#011validation-logloss:0.42892
# [11]#011train-logloss:0.40503#011validation-logloss:0.42547
# [12]#011train-logloss:0.40169#011validation-logloss:0.42265
# [13]#011train-logloss:0.39877#011validation-logloss:0.42016
# [14]#011train-logloss:0.39649#011validation-logloss:0.41828
# [15]#011train-logloss:0.39485#011validation-logloss:0.41693
# [16]#011train-logloss:0.39321#011validation-logloss:0.41580
# [17]#011train-logloss:0.39182#011validation-logloss:0.41470
# [18]#011train-logloss:0.39089#011validation-logloss:0.41410
# [19]#011train-logloss:0.38970#011validation-logloss:0.41318
# [20]#011train-logloss:0.38878#011validation-logloss:0.41250
# [21]#011train-logloss:0.38814#011validation-logloss:0.41210
# [22]#011train-logloss:0.38739#011validation-logloss:0.41154
# [23]#011train-logloss:0.38684#011validation-logloss:0.41119
# [24]#011train-logloss:0.38640#011validation-logloss:0.41091
# [25]#011train-logloss:0.38587#011validation-logloss:0.41068
# [26]#011train-logloss:0.38552#011validation-logloss:0.41049
# [27]#011train-logloss:0.38518#011validation-logloss:0.41030
# [28]#011train-logloss:0.38475#011validation-logloss:0.41003
# [29]#011train-logloss:0.38448#011validation-logloss:0.40993
# [30]#011train-logloss:0.38421#011validation-logloss:0.40975
# [31]#011train-logloss:0.38398#011validation-logloss:0.40967
# [32]#011train-logloss:0.38378#011validation-logloss:0.40952
# [33]#011train-logloss:0.38360#011validation-logloss:0.40941
# [34]#011train-logloss:0.38335#011validation-logloss:0.40937
# [35]#011train-logloss:0.38307#011validation-logloss:0.40926
# [36]#011train-logloss:0.38277#011validation-logloss:0.40912
# [37]#011train-logloss:0.38254#011validation-logloss:0.40897
# [38]#011train-logloss:0.38241#011validation-logloss:0.40883
# [39]#011train-logloss:0.38237#011validation-logloss:0.40880
# [40]#011train-logloss:0.38215#011validation-logloss:0.40875
# [41]#011train-logloss:0.38203#011validation-logloss:0.40871
# [42]#011train-logloss:0.38186#011validation-logloss:0.40871
# [43]#011train-logloss:0.38177#011validation-logloss:0.40871
# [44]#011train-logloss:0.38167#011validation-logloss:0.40868
# [45]#011train-logloss:0.38142#011validation-logloss:0.40855
# [46]#011train-logloss:0.38127#011validation-logloss:0.40851
# [47]#011train-logloss:0.38119#011validation-logloss:0.40845
# [48]#011train-logloss:0.38110#011validation-logloss:0.40846
# [49]#011train-logloss:0.38102#011validation-logloss:0.40848
# [50]#011train-logloss:0.38090#011validation-logloss:0.40848
# [51]#011train-logloss:0.38077#011validation-logloss:0.40841
# [52]#011train-logloss:0.38061#011validation-logloss:0.40836
# [53]#011train-logloss:0.38050#011validation-logloss:0.40834
# [54]#011train-logloss:0.38043#011validation-logloss:0.40832
# [55]#011train-logloss:0.38036#011validation-logloss:0.40833
# [56]#011train-logloss:0.38021#011validation-logloss:0.40836
# [57]#011train-logloss:0.38016#011validation-logloss:0.40831
# [58]#011train-logloss:0.38009#011validation-logloss:0.40831
# [59]#011train-logloss:0.38001#011validation-logloss:0.40837
# [60]#011train-logloss:0.37993#011validation-logloss:0.40833
# [61]#011train-logloss:0.37982#011validation-logloss:0.40838
# [62]#011train-logloss:0.37972#011validation-logloss:0.40841
# [63]#011train-logloss:0.37966#011validation-logloss:0.40839
# [64]#011train-logloss:0.37953#011validation-logloss:0.40835
# [65]#011train-logloss:0.37944#011validation-logloss:0.40831
# [66]#011train-logloss:0.37932#011validation-logloss:0.40834
# [67]#011train-logloss:0.37929#011validation-logloss:0.40835
# [68]#011train-logloss:0.37922#011validation-logloss:0.40840
# [69]#011train-logloss:0.37918#011validation-logloss:0.40841
# [70]#011train-logloss:0.37915#011validation-logloss:0.40841
# [71]#011train-logloss:0.37907#011validation-logloss:0.40838
# [72]#011train-logloss:0.37898#011validation-logloss:0.40837
# [73]#011train-logloss:0.37897#011validation-logloss:0.40838
# [74]#011train-logloss:0.37883#011validation-logloss:0.40836
# [75]#011train-logloss:0.37875#011validation-logloss:0.40832
# [76]#011train-logloss:0.37865#011validation-logloss:0.40831
# [77]#011train-logloss:0.37861#011validation-logloss:0.40833
# [78]#011train-logloss:0.37852#011validation-logloss:0.40828
# [79]#011train-logloss:0.37849#011validation-logloss:0.40829
# [80]#011train-logloss:0.37840#011validation-logloss:0.40829
# [81]#011train-logloss:0.37838#011validation-logloss:0.40829
# [82]#011train-logloss:0.37832#011validation-logloss:0.40832
# [83]#011train-logloss:0.37826#011validation-logloss:0.40833
# [84]#011train-logloss:0.37821#011validation-logloss:0.40830
# [85]#011train-logloss:0.37810#011validation-logloss:0.40830
# [86]#011train-logloss:0.37800#011validation-logloss:0.40823
# [87]#011train-logloss:0.37795#011validation-logloss:0.40822
# [88]#011train-logloss:0.37791#011validation-logloss:0.40821
# [89]#011train-logloss:0.37779#011validation-logloss:0.40821
# [90]#011train-logloss:0.37774#011validation-logloss:0.40821
# [91]#011train-logloss:0.37770#011validation-logloss:0.40820
# [92]#011train-logloss:0.37768#011validation-logloss:0.40817
# [93]#011train-logloss:0.37766#011validation-logloss:0.40818
# [94]#011train-logloss:0.37760#011validation-logloss:0.40816
# [95]#011train-logloss:0.37757#011validation-logloss:0.40816
# [96]#011train-logloss:0.37752#011validation-logloss:0.40816
# [97]#011train-logloss:0.37737#011validation-logloss:0.40811
# [98]#011train-logloss:0.37731#011validation-logloss:0.40816
# [99]#011train-logloss:0.37729#011validation-logloss:0.40816
# [100]#011train-logloss:0.37721#011validation-logloss:0.40818
# [101]#011train-logloss:0.37716#011validation-logloss:0.40819
# [102]#011train-logloss:0.37710#011validation-logloss:0.40817
# [103]#011train-logloss:0.37706#011validation-logloss:0.40820
# [104]#011train-logloss:0.37706#011validation-logloss:0.40821
# [105]#011train-logloss:0.37703#011validation-logloss:0.40821
# [106]#011train-logloss:0.37702#011validation-logloss:0.40821
# [107]#011train-logloss:0.37700#011validation-logloss:0.40818
# [108]#011train-logloss:0.37695#011validation-logloss:0.40817
# [109]#011train-logloss:0.37689#011validation-logloss:0.40817
# [110]#011train-logloss:0.37684#011validation-logloss:0.40816
# [111]#011train-logloss:0.37682#011validation-logloss:0.40815
# [112]#011train-logloss:0.37675#011validation-logloss:0.40819
# [113]#011train-logloss:0.37671#011validation-logloss:0.40820
# [114]#011train-logloss:0.37669#011validation-logloss:0.40819
# [115]#011train-logloss:0.37666#011validation-logloss:0.40816
# [116]#011train-logloss:0.37661#011validation-logloss:0.40819
# [117]#011train-logloss:0.37656#011validation-logloss:0.40819
# [118]#011train-logloss:0.37648#011validation-logloss:0.40818
# [119]#011train-logloss:0.37647#011validation-logloss:0.40817
# [120]#011train-logloss:0.37647#011validation-logloss:0.40818
# [121]#011train-logloss:0.37640#011validation-logloss:0.40819
# [122]#011train-logloss:0.37637#011validation-logloss:0.40819
# [123]#011train-logloss:0.37627#011validation-logloss:0.40815
# [124]#011train-logloss:0.37621#011validation-logloss:0.40816
# [125]#011train-logloss:0.37616#011validation-logloss:0.40816
# [126]#011train-logloss:0.37611#011validation-logloss:0.40818
# [127]#011train-logloss:0.37608#011validation-logloss:0.40820
# [128]#011train-logloss:0.37604#011validation-logloss:0.40824
# [129]#011train-logloss:0.37598#011validation-logloss:0.40822
# [130]#011train-logloss:0.37595#011validation-logloss:0.40822
# [131]#011train-logloss:0.37595#011validation-logloss:0.40823
# [132]#011train-logloss:0.37591#011validation-logloss:0.40819
# [133]#011train-logloss:0.37587#011validation-logloss:0.40819
# [134]#011train-logloss:0.37586#011validation-logloss:0.40818
# [135]#011train-logloss:0.37585#011validation-logloss:0.40821
# [136]#011train-logloss:0.37582#011validation-logloss:0.40824
# [137]#011train-logloss:0.37578#011validation-logloss:0.40822
# [138]#011train-logloss:0.37577#011validation-logloss:0.40819
# [139]#011train-logloss:0.37576#011validation-logloss:0.40820
# [140]#011train-logloss:0.37571#011validation-logloss:0.40819
# [141]#011train-logloss:0.37566#011validation-logloss:0.40823
# [142]#011train-logloss:0.37563#011validation-logloss:0.40823
# [143]#011train-logloss:0.37556#011validation-logloss:0.40825
# [144]#011train-logloss:0.37550#011validation-logloss:0.40827
# [145]#011train-logloss:0.37550#011validation-logloss:0.40828
# [146]#011train-logloss:0.37547#011validation-logloss:0.40827
# [147]#011train-logloss:0.37547#011validation-logloss:0.40828
# [148]#011train-logloss:0.37546#011validation-logloss:0.40827
# [149]#011train-logloss:0.37542#011validation-logloss:0.40827
# [150]#011train-logloss:0.37542#011validation-logloss:0.40827
# [151]#011train-logloss:0.37539#011validation-logloss:0.40825
# [152]#011train-logloss:0.37538#011validation-logloss:0.40829
# [153]#011train-logloss:0.37537#011validation-logloss:0.40830
# [154]#011train-logloss:0.37535#011validation-logloss:0.40832
# [155]#011train-logloss:0.37526#011validation-logloss:0.40831
# [156]#011train-logloss:0.37526#011validation-logloss:0.40831
# [157]#011train-logloss:0.37518#011validation-logloss:0.40831
# [158]#011train-logloss:0.37517#011validation-logloss:0.40833
# [159]#011train-logloss:0.37513#011validation-logloss:0.40833
# [160]#011train-logloss:0.37511#011validation-logloss:0.40834
# [161]#011train-logloss:0.37507#011validation-logloss:0.40836
# [162]#011train-logloss:0.37506#011validation-logloss:0.40832
# [163]#011train-logloss:0.37505#011validation-logloss:0.40832
# [164]#011train-logloss:0.37505#011validation-logloss:0.40834
# [165]#011train-logloss:0.37498#011validation-logloss:0.40831
# [166]#011train-logloss:0.37497#011validation-logloss:0.40833
# [167]#011train-logloss:0.37494#011validation-logloss:0.40834
# [168]#011train-logloss:0.37494#011validation-logloss:0.40836
# [169]#011train-logloss:0.37490#011validation-logloss:0.40834
# [170]#011train-logloss:0.37482#011validation-logloss:0.40834
# [171]#011train-logloss:0.37481#011validation-logloss:0.40835
# [172]#011train-logloss:0.37476#011validation-logloss:0.40832
# [173]#011train-logloss:0.37476#011validation-logloss:0.40832
# [174]#011train-logloss:0.37476#011validation-logloss:0.40831
# [175]#011train-logloss:0.37472#011validation-logloss:0.40831
# [176]#011train-logloss:0.37471#011validation-logloss:0.40830
# [177]#011train-logloss:0.37469#011validation-logloss:0.40829
# [178]#011train-logloss:0.37469#011validation-logloss:0.40822
# [179]#011train-logloss:0.37469#011validation-logloss:0.40825
# [180]#011train-logloss:0.37466#011validation-logloss:0.40826
# [181]#011train-logloss:0.37463#011validation-logloss:0.40827
# [182]#011train-logloss:0.37462#011validation-logloss:0.40829
# [183]#011train-logloss:0.37460#011validation-logloss:0.40830
# [184]#011train-logloss:0.37460#011validation-logloss:0.40827
# [185]#011train-logloss:0.37459#011validation-logloss:0.40829
# [186]#011train-logloss:0.37457#011validation-logloss:0.40831
# [187]#011train-logloss:0.37451#011validation-logloss:0.40830
# [188]#011train-logloss:0.37444#011validation-logloss:0.40828
# [189]#011train-logloss:0.37442#011validation-logloss:0.40829
# [190]#011train-logloss:0.37440#011validation-logloss:0.40835
# [191]#011train-logloss:0.37440#011validation-logloss:0.40834
# [192]#011train-logloss:0.37438#011validation-logloss:0.40834
# [193]#011train-logloss:0.37439#011validation-logloss:0.40832
# [194]#011train-logloss:0.37435#011validation-logloss:0.40835
# [195]#011train-logloss:0.37434#011validation-logloss:0.40835
# [196]#011train-logloss:0.37429#011validation-logloss:0.40831
# [197]#011train-logloss:0.37428#011validation-logloss:0.40833
# [198]#011train-logloss:0.37426#011validation-logloss:0.40829
# [199]#011train-logloss:0.37421#011validation-logloss:0.40835
# [200]#011train-logloss:0.37418#011validation-logloss:0.40835
# [201]#011train-logloss:0.37418#011validation-logloss:0.40834
# [202]#011train-logloss:0.37415#011validation-logloss:0.40828
# [203]#011train-logloss:0.37414#011validation-logloss:0.40826
# [204]#011train-logloss:0.37408#011validation-logloss:0.40829
# [205]#011train-logloss:0.37406#011validation-logloss:0.40829
# [206]#011train-logloss:0.37406#011validation-logloss:0.40832
# [207]#011train-logloss:0.37406#011validation-logloss:0.40835
# [208]#011train-logloss:0.37403#011validation-logloss:0.40833
# [209]#011train-logloss:0.37397#011validation-logloss:0.40835
# [210]#011train-logloss:0.37397#011validation-logloss:0.40836
# [211]#011train-logloss:0.37389#011validation-logloss:0.40836
# [212]#011train-logloss:0.37387#011validation-logloss:0.40838
# [213]#011train-logloss:0.37385#011validation-logloss:0.40840
# [214]#011train-logloss:0.37383#011validation-logloss:0.40837
# [215]#011train-logloss:0.37381#011validation-logloss:0.40836
# [216]#011train-logloss:0.37380#011validation-logloss:0.40837
# [217]#011train-logloss:0.37376#011validation-logloss:0.40838
# [218]#011train-logloss:0.37372#011validation-logloss:0.40836
# [219]#011train-logloss:0.37368#011validation-logloss:0.40836
# [220]#011train-logloss:0.37368#011validation-logloss:0.40836
# [221]#011train-logloss:0.37367#011validation-logloss:0.40840
# [222]#011train-logloss:0.37361#011validation-logloss:0.40840
# [223]#011train-logloss:0.37357#011validation-logloss:0.40841
# [224]#011train-logloss:0.37353#011validation-logloss:0.40839
# [225]#011train-logloss:0.37353#011validation-logloss:0.40837
# [226]#011train-logloss:0.37350#011validation-logloss:0.40843
# [227]#011train-logloss:0.37348#011validation-logloss:0.40842
# [228]#011train-logloss:0.37344#011validation-logloss:0.40846
# [229]#011train-logloss:0.37340#011validation-logloss:0.40847
# [230]#011train-logloss:0.37339#011validation-logloss:0.40846
# [231]#011train-logloss:0.37339#011validation-logloss:0.40847
# [232]#011train-logloss:0.37334#011validation-logloss:0.40845
# [233]#011train-logloss:0.37332#011validation-logloss:0.40848
# [234]#011train-logloss:0.37329#011validation-logloss:0.40851
# [235]#011train-logloss:0.37328#011validation-logloss:0.40854
# [236]#011train-logloss:0.37324#011validation-logloss:0.40859
# [237]#011train-logloss:0.37320#011validation-logloss:0.40857
# [238]#011train-logloss:0.37317#011validation-logloss:0.40857
# [239]#011train-logloss:0.37314#011validation-logloss:0.40856
# [240]#011train-logloss:0.37313#011validation-logloss:0.40858
# [241]#011train-logloss:0.37313#011validation-logloss:0.40856
# [242]#011train-logloss:0.37308#011validation-logloss:0.40856
# [243]#011train-logloss:0.37305#011validation-logloss:0.40855
# [244]#011train-logloss:0.37303#011validation-logloss:0.40858
# [245]#011train-logloss:0.37303#011validation-logloss:0.40858
# [246]#011train-logloss:0.37302#011validation-logloss:0.40863
# [247]#011train-logloss:0.37299#011validation-logloss:0.40864
# [248]#011train-logloss:0.37299#011validation-logloss:0.40862
# [249]#011train-logloss:0.37298#011validation-logloss:0.40859
# [250]#011train-logloss:0.37295#011validation-logloss:0.40862
# [251]#011train-logloss:0.37289#011validation-logloss:0.40865
# [252]#011train-logloss:0.37286#011validation-logloss:0.40864
# [253]#011train-logloss:0.37285#011validation-logloss:0.40866
# [254]#011train-logloss:0.37285#011validation-logloss:0.40867
# [255]#011train-logloss:0.37284#011validation-logloss:0.40865
# [256]#011train-logloss:0.37282#011validation-logloss:0.40867
# [257]#011train-logloss:0.37282#011validation-logloss:0.40864
# [258]#011train-logloss:0.37279#011validation-logloss:0.40864
# [259]#011train-logloss:0.37278#011validation-logloss:0.40866
# [260]#011train-logloss:0.37276#011validation-logloss:0.40861
# [261]#011train-logloss:0.37270#011validation-logloss:0.40863
# [262]#011train-logloss:0.37266#011validation-logloss:0.40865
# [263]#011train-logloss:0.37264#011validation-logloss:0.40869
# [264]#011train-logloss:0.37263#011validation-logloss:0.40867
# [265]#011train-logloss:0.37259#011validation-logloss:0.40867
# [266]#011train-logloss:0.37255#011validation-logloss:0.40873
# [267]#011train-logloss:0.37253#011validation-logloss:0.40873
# [268]#011train-logloss:0.37251#011validation-logloss:0.40874
# [269]#011train-logloss:0.37251#011validation-logloss:0.40872
# [270]#011train-logloss:0.37249#011validation-logloss:0.40869
# [271]#011train-logloss:0.37249#011validation-logloss:0.40869
# [272]#011train-logloss:0.37246#011validation-logloss:0.40871
# [273]#011train-logloss:0.37241#011validation-logloss:0.40869
# [274]#011train-logloss:0.37236#011validation-logloss:0.40868
# [275]#011train-logloss:0.37232#011validation-logloss:0.40866
# [276]#011train-logloss:0.37228#011validation-logloss:0.40869
# [277]#011train-logloss:0.37227#011validation-logloss:0.40869
# [278]#011train-logloss:0.37223#011validation-logloss:0.40871
# [279]#011train-logloss:0.37221#011validation-logloss:0.40874
# [280]#011train-logloss:0.37218#011validation-logloss:0.40871
# [281]#011train-logloss:0.37217#011validation-logloss:0.40873
# [282]#011train-logloss:0.37214#011validation-logloss:0.40872
# [283]#011train-logloss:0.37208#011validation-logloss:0.40874
# [284]#011train-logloss:0.37206#011validation-logloss:0.40872
# [285]#011train-logloss:0.37205#011validation-logloss:0.40875
# [286]#011train-logloss:0.37201#011validation-logloss:0.40874
# [287]#011train-logloss:0.37202#011validation-logloss:0.40874
# [288]#011train-logloss:0.37197#011validation-logloss:0.40875
# [289]#011train-logloss:0.37195#011validation-logloss:0.40875
# [290]#011train-logloss:0.37193#011validation-logloss:0.40876
# [291]#011train-logloss:0.37190#011validation-logloss:0.40876
# [292]#011train-logloss:0.37189#011validation-logloss:0.40874
# [293]#011train-logloss:0.37186#011validation-logloss:0.40875
# [294]#011train-logloss:0.37186#011validation-logloss:0.40874
# [295]#011train-logloss:0.37186#011validation-logloss:0.40875
# [296]#011train-logloss:0.37179#011validation-logloss:0.40875
# [297]#011train-logloss:0.37175#011validation-logloss:0.40880
# [298]#011train-logloss:0.37174#011validation-logloss:0.40880
# [299]#011train-logloss:0.37174#011validation-logloss:0.40880
# [300]#011train-logloss:0.37172#011validation-logloss:0.40877
# [301]#011train-logloss:0.37170#011validation-logloss:0.40876
# [302]#011train-logloss:0.37166#011validation-logloss:0.40878
# [303]#011train-logloss:0.37164#011validation-logloss:0.40879
# [304]#011train-logloss:0.37164#011validation-logloss:0.40880
# [305]#011train-logloss:0.37164#011validation-logloss:0.40881
# [306]#011train-logloss:0.37161#011validation-logloss:0.40879
# [307]#011train-logloss:0.37160#011validation-logloss:0.40881
# [308]#011train-logloss:0.37160#011validation-logloss:0.40879
# [309]#011train-logloss:0.37157#011validation-logloss:0.40879
# [310]#011train-logloss:0.37157#011validation-logloss:0.40881
# [311]#011train-logloss:0.37156#011validation-logloss:0.40882
# [312]#011train-logloss:0.37156#011validation-logloss:0.40882
# [313]#011train-logloss:0.37156#011validation-logloss:0.40881
# [314]#011train-logloss:0.37154#011validation-logloss:0.40880
# [315]#011train-logloss:0.37149#011validation-logloss:0.40881
# [316]#011train-logloss:0.37149#011validation-logloss:0.40880
# [317]#011train-logloss:0.37149#011validation-logloss:0.40880
# [318]#011train-logloss:0.37147#011validation-logloss:0.40879
# [319]#011train-logloss:0.37144#011validation-logloss:0.40880
# [320]#011train-logloss:0.37144#011validation-logloss:0.40880
# [321]#011train-logloss:0.37143#011validation-logloss:0.40881
# [322]#011train-logloss:0.37142#011validation-logloss:0.40884
# [323]#011train-logloss:0.37139#011validation-logloss:0.40882
# [324]#011train-logloss:0.37136#011validation-logloss:0.40886
# [325]#011train-logloss:0.37135#011validation-logloss:0.40888
# [326]#011train-logloss:0.37132#011validation-logloss:0.40886
# [327]#011train-logloss:0.37131#011validation-logloss:0.40884
# [328]#011train-logloss:0.37126#011validation-logloss:0.40886
# [329]#011train-logloss:0.37125#011validation-logloss:0.40887
# [330]#011train-logloss:0.37121#011validation-logloss:0.40891
# [331]#011train-logloss:0.37116#011validation-logloss:0.40891
# [332]#011train-logloss:0.37116#011validation-logloss:0.40890
# [333]#011train-logloss:0.37114#011validation-logloss:0.40888
# [334]#011train-logloss:0.37112#011validation-logloss:0.40889
# [335]#011train-logloss:0.37110#011validation-logloss:0.40889
# [336]#011train-logloss:0.37108#011validation-logloss:0.40891
# [337]#011train-logloss:0.37107#011validation-logloss:0.40893
# [338]#011train-logloss:0.37107#011validation-logloss:0.40892
# [339]#011train-logloss:0.37107#011validation-logloss:0.40893
# [340]#011train-logloss:0.37105#011validation-logloss:0.40893
# [341]#011train-logloss:0.37103#011validation-logloss:0.40892
# [342]#011train-logloss:0.37102#011validation-logloss:0.40893
# [343]#011train-logloss:0.37101#011validation-logloss:0.40896
# [344]#011train-logloss:0.37101#011validation-logloss:0.40894
# [345]#011train-logloss:0.37101#011validation-logloss:0.40893
# [346]#011train-logloss:0.37092#011validation-logloss:0.40895
# [347]#011train-logloss:0.37092#011validation-logloss:0.40892
# [348]#011train-logloss:0.37090#011validation-logloss:0.40896
# [349]#011train-logloss:0.37090#011validation-logloss:0.40897
# [350]#011train-logloss:0.37089#011validation-logloss:0.40896
# [351]#011train-logloss:0.37089#011validation-logloss:0.40898
# [352]#011train-logloss:0.37088#011validation-logloss:0.40899
# [353]#011train-logloss:0.37086#011validation-logloss:0.40900
# [354]#011train-logloss:0.37084#011validation-logloss:0.40899
# [355]#011train-logloss:0.37084#011validation-logloss:0.40899
# [356]#011train-logloss:0.37080#011validation-logloss:0.40903
# [357]#011train-logloss:0.37080#011validation-logloss:0.40902
# [358]#011train-logloss:0.37080#011validation-logloss:0.40902
# [359]#011train-logloss:0.37077#011validation-logloss:0.40902
# [360]#011train-logloss:0.37077#011validation-logloss:0.40901
# [361]#011train-logloss:0.37077#011validation-logloss:0.40899
# [362]#011train-logloss:0.37077#011validation-logloss:0.40899
# [363]#011train-logloss:0.37075#011validation-logloss:0.40900
# [364]#011train-logloss:0.37075#011validation-logloss:0.40901
# [365]#011train-logloss:0.37073#011validation-logloss:0.40905
# [366]#011train-logloss:0.37071#011validation-logloss:0.40908
# [367]#011train-logloss:0.37070#011validation-logloss:0.40906
# [368]#011train-logloss:0.37069#011validation-logloss:0.40910
# [369]#011train-logloss:0.37069#011validation-logloss:0.40908
# [370]#011train-logloss:0.37066#011validation-logloss:0.40911
# [371]#011train-logloss:0.37066#011validation-logloss:0.40911
# [372]#011train-logloss:0.37066#011validation-logloss:0.40910
# [373]#011train-logloss:0.37065#011validation-logloss:0.40907
# [374]#011train-logloss:0.37065#011validation-logloss:0.40909
# [375]#011train-logloss:0.37065#011validation-logloss:0.40910
# [376]#011train-logloss:0.37063#011validation-logloss:0.40908
# [377]#011train-logloss:0.37062#011validation-logloss:0.40908
# [378]#011train-logloss:0.37058#011validation-logloss:0.40910
# [379]#011train-logloss:0.37058#011validation-logloss:0.40912
# [380]#011train-logloss:0.37056#011validation-logloss:0.40910
# [381]#011train-logloss:0.37054#011validation-logloss:0.40910
# [382]#011train-logloss:0.37054#011validation-logloss:0.40916
# [383]#011train-logloss:0.37051#011validation-logloss:0.40915
# [384]#011train-logloss:0.37051#011validation-logloss:0.40913
# [385]#011train-logloss:0.37047#011validation-logloss:0.40908
# [386]#011train-logloss:0.37045#011validation-logloss:0.40908
# [387]#011train-logloss:0.37042#011validation-logloss:0.40910
# [388]#011train-logloss:0.37041#011validation-logloss:0.40912
# [389]#011train-logloss:0.37036#011validation-logloss:0.40914
# [390]#011train-logloss:0.37033#011validation-logloss:0.40914
# [391]#011train-logloss:0.37033#011validation-logloss:0.40915
# [392]#011train-logloss:0.37032#011validation-logloss:0.40915
# [393]#011train-logloss:0.37030#011validation-logloss:0.40912
# [394]#011train-logloss:0.37028#011validation-logloss:0.40911
# [395]#011train-logloss:0.37028#011validation-logloss:0.40909
# [396]#011train-logloss:0.37027#011validation-logloss:0.40913
# [397]#011train-logloss:0.37021#011validation-logloss:0.40914
# [398]#011train-logloss:0.37020#011validation-logloss:0.40912
# [399]#011train-logloss:0.37020#011validation-logloss:0.40913
# [400]#011train-logloss:0.37019#011validation-logloss:0.40917
# [401]#011train-logloss:0.37018#011validation-logloss:0.40917
# [402]#011train-logloss:0.37018#011validation-logloss:0.40918
# [403]#011train-logloss:0.37018#011validation-logloss:0.40919
# [404]#011train-logloss:0.37018#011validation-logloss:0.40916
# [405]#011train-logloss:0.37016#011validation-logloss:0.40913
# [406]#011train-logloss:0.37016#011validation-logloss:0.40916
# [407]#011train-logloss:0.37013#011validation-logloss:0.40914
# [408]#011train-logloss:0.37009#011validation-logloss:0.40919
# [409]#011train-logloss:0.37007#011validation-logloss:0.40921
# [410]#011train-logloss:0.37007#011validation-logloss:0.40921
# [411]#011train-logloss:0.37007#011validation-logloss:0.40920
# [412]#011train-logloss:0.37005#011validation-logloss:0.40921
# [413]#011train-logloss:0.37002#011validation-logloss:0.40924
# [414]#011train-logloss:0.37002#011validation-logloss:0.40925
# [415]#011train-logloss:0.37002#011validation-logloss:0.40922
# [416]#011train-logloss:0.37000#011validation-logloss:0.40921
# [417]#011train-logloss:0.37000#011validation-logloss:0.40921
# [418]#011train-logloss:0.36998#011validation-logloss:0.40920
# [419]#011train-logloss:0.36998#011validation-logloss:0.40923
# [420]#011train-logloss:0.36995#011validation-logloss:0.40928
# [421]#011train-logloss:0.36994#011validation-logloss:0.40929
# [422]#011train-logloss:0.36992#011validation-logloss:0.40929
# [423]#011train-logloss:0.36990#011validation-logloss:0.40927
# [424]#011train-logloss:0.36990#011validation-logloss:0.40927
# [425]#011train-logloss:0.36990#011validation-logloss:0.40928
# [426]#011train-logloss:0.36990#011validation-logloss:0.40926
# [427]#011train-logloss:0.36987#011validation-logloss:0.40929
# [428]#011train-logloss:0.36987#011validation-logloss:0.40927
# [429]#011train-logloss:0.36981#011validation-logloss:0.40929
# [430]#011train-logloss:0.36981#011validation-logloss:0.40925
# [431]#011train-logloss:0.36981#011validation-logloss:0.40923
# [432]#011train-logloss:0.36980#011validation-logloss:0.40921
# [433]#011train-logloss:0.36980#011validation-logloss:0.40923
# [434]#011train-logloss:0.36977#011validation-logloss:0.40928
# [435]#011train-logloss:0.36975#011validation-logloss:0.40928
# [436]#011train-logloss:0.36975#011validation-logloss:0.40927
# [437]#011train-logloss:0.36971#011validation-logloss:0.40926
# [438]#011train-logloss:0.36964#011validation-logloss:0.40927
# [439]#011train-logloss:0.36961#011validation-logloss:0.40930
# [440]#011train-logloss:0.36960#011validation-logloss:0.40929
# [441]#011train-logloss:0.36958#011validation-logloss:0.40929
# [442]#011train-logloss:0.36955#011validation-logloss:0.40936
# [443]#011train-logloss:0.36953#011validation-logloss:0.40937
# [444]#011train-logloss:0.36952#011validation-logloss:0.40936
# [445]#011train-logloss:0.36950#011validation-logloss:0.40934
# [446]#011train-logloss:0.36951#011validation-logloss:0.40936
# [447]#011train-logloss:0.36950#011validation-logloss:0.40936
# [448]#011train-logloss:0.36950#011validation-logloss:0.40936
# [449]#011train-logloss:0.36950#011validation-logloss:0.40938
# [450]#011train-logloss:0.36950#011validation-logloss:0.40937
# [451]#011train-logloss:0.36950#011validation-logloss:0.40937
# [452]#011train-logloss:0.36950#011validation-logloss:0.40935
# [453]#011train-logloss:0.36947#011validation-logloss:0.40939
# [454]#011train-logloss:0.36944#011validation-logloss:0.40936
# [455]#011train-logloss:0.36942#011validation-logloss:0.40934
# [456]#011train-logloss:0.36939#011validation-logloss:0.40937
# [457]#011train-logloss:0.36939#011validation-logloss:0.40940
# [458]#011train-logloss:0.36937#011validation-logloss:0.40937
# [459]#011train-logloss:0.36936#011validation-logloss:0.40935
# [460]#011train-logloss:0.36936#011validation-logloss:0.40938
# [461]#011train-logloss:0.36933#011validation-logloss:0.40939
# [462]#011train-logloss:0.36932#011validation-logloss:0.40938
# [463]#011train-logloss:0.36930#011validation-logloss:0.40938
# [464]#011train-logloss:0.36929#011validation-logloss:0.40938
# [465]#011train-logloss:0.36927#011validation-logloss:0.40939
# [466]#011train-logloss:0.36926#011validation-logloss:0.40943
# [467]#011train-logloss:0.36922#011validation-logloss:0.40944
# [468]#011train-logloss:0.36921#011validation-logloss:0.40940
# [469]#011train-logloss:0.36919#011validation-logloss:0.40940
# [470]#011train-logloss:0.36919#011validation-logloss:0.40942
# [471]#011train-logloss:0.36919#011validation-logloss:0.40940
# [472]#011train-logloss:0.36918#011validation-logloss:0.40938
# [473]#011train-logloss:0.36916#011validation-logloss:0.40936
# [474]#011train-logloss:0.36915#011validation-logloss:0.40938
# [475]#011train-logloss:0.36911#011validation-logloss:0.40939
# [476]#011train-logloss:0.36911#011validation-logloss:0.40939
# [477]#011train-logloss:0.36911#011validation-logloss:0.40938
# [478]#011train-logloss:0.36910#011validation-logloss:0.40939
# [479]#011train-logloss:0.36910#011validation-logloss:0.40942
# [480]#011train-logloss:0.36909#011validation-logloss:0.40946
# [481]#011train-logloss:0.36906#011validation-logloss:0.40947
# [482]#011train-logloss:0.36906#011validation-logloss:0.40949
# [483]#011train-logloss:0.36904#011validation-logloss:0.40952
# [484]#011train-logloss:0.36902#011validation-logloss:0.40951
# [485]#011train-logloss:0.36900#011validation-logloss:0.40951
# [486]#011train-logloss:0.36900#011validation-logloss:0.40950
# [487]#011train-logloss:0.36899#011validation-logloss:0.40951
# [488]#011train-logloss:0.36897#011validation-logloss:0.40949
# [489]#011train-logloss:0.36897#011validation-logloss:0.40947
# [490]#011train-logloss:0.36897#011validation-logloss:0.40946
# [491]#011train-logloss:0.36897#011validation-logloss:0.40946
# [492]#011train-logloss:0.36896#011validation-logloss:0.40943
# [493]#011train-logloss:0.36894#011validation-logloss:0.40944
# [494]#011train-logloss:0.36894#011validation-logloss:0.40943
# [495]#011train-logloss:0.36892#011validation-logloss:0.40943
# [496]#011train-logloss:0.36891#011validation-logloss:0.40943
# [497]#011train-logloss:0.36891#011validation-logloss:0.40941
# [498]#011train-logloss:0.36891#011validation-logloss:0.40941
# [499]#011train-logloss:0.36890#011validation-logloss:0.40943
# [500]#011train-logloss:0.36887#011validation-logloss:0.40948
# [501]#011train-logloss:0.36887#011validation-logloss:0.40951
# [502]#011train-logloss:0.36887#011validation-logloss:0.40952
# [503]#011train-logloss:0.36885#011validation-logloss:0.40956
# [504]#011train-logloss:0.36884#011validation-logloss:0.40955
# [505]#011train-logloss:0.36884#011validation-logloss:0.40952
# [506]#011train-logloss:0.36881#011validation-logloss:0.40955
# [507]#011train-logloss:0.36878#011validation-logloss:0.40956
# [508]#011train-logloss:0.36875#011validation-logloss:0.40957
# [509]#011train-logloss:0.36876#011validation-logloss:0.40956
# [510]#011train-logloss:0.36875#011validation-logloss:0.40952
# [511]#011train-logloss:0.36871#011validation-logloss:0.40954
# [512]#011train-logloss:0.36871#011validation-logloss:0.40955
# [513]#011train-logloss:0.36868#011validation-logloss:0.40959
# [514]#011train-logloss:0.36868#011validation-logloss:0.40958
# [515]#011train-logloss:0.36867#011validation-logloss:0.40956
# [516]#011train-logloss:0.36867#011validation-logloss:0.40959
# [517]#011train-logloss:0.36864#011validation-logloss:0.40960
# [518]#011train-logloss:0.36862#011validation-logloss:0.40959
# [519]#011train-logloss:0.36862#011validation-logloss:0.40957
# [520]#011train-logloss:0.36862#011validation-logloss:0.40957
# [521]#011train-logloss:0.36862#011validation-logloss:0.40959
# [522]#011train-logloss:0.36861#011validation-logloss:0.40957
# [523]#011train-logloss:0.36860#011validation-logloss:0.40958
# [524]#011train-logloss:0.36860#011validation-logloss:0.40958
# [525]#011train-logloss:0.36858#011validation-logloss:0.40956
# [526]#011train-logloss:0.36858#011validation-logloss:0.40953
# [527]#011train-logloss:0.36857#011validation-logloss:0.40953
# [528]#011train-logloss:0.36856#011validation-logloss:0.40953
# [529]#011train-logloss:0.36856#011validation-logloss:0.40956
# [530]#011train-logloss:0.36855#011validation-logloss:0.40955
# [531]#011train-logloss:0.36853#011validation-logloss:0.40953
# [532]#011train-logloss:0.36851#011validation-logloss:0.40955
# [533]#011train-logloss:0.36850#011validation-logloss:0.40954
# [534]#011train-logloss:0.36850#011validation-logloss:0.40953
# [535]#011train-logloss:0.36842#011validation-logloss:0.40958
# [536]#011train-logloss:0.36841#011validation-logloss:0.40960
# [537]#011train-logloss:0.36841#011validation-logloss:0.40960
# [538]#011train-logloss:0.36838#011validation-logloss:0.40964
# [539]#011train-logloss:0.36838#011validation-logloss:0.40963
# [540]#011train-logloss:0.36836#011validation-logloss:0.40964
# [541]#011train-logloss:0.36834#011validation-logloss:0.40961
# [542]#011train-logloss:0.36834#011validation-logloss:0.40960
# [543]#011train-logloss:0.36830#011validation-logloss:0.40961
# [544]#011train-logloss:0.36828#011validation-logloss:0.40963
# [545]#011train-logloss:0.36827#011validation-logloss:0.40965
# [546]#011train-logloss:0.36826#011validation-logloss:0.40963
# [547]#011train-logloss:0.36826#011validation-logloss:0.40967
# [548]#011train-logloss:0.36822#011validation-logloss:0.40971
# [549]#011train-logloss:0.36816#011validation-logloss:0.40971
# [550]#011train-logloss:0.36816#011validation-logloss:0.40968
# [551]#011train-logloss:0.36814#011validation-logloss:0.40969
# [552]#011train-logloss:0.36811#011validation-logloss:0.40972
# [553]#011train-logloss:0.36811#011validation-logloss:0.40971
# [554]#011train-logloss:0.36810#011validation-logloss:0.40971
# [555]#011train-logloss:0.36808#011validation-logloss:0.40970
# [556]#011train-logloss:0.36808#011validation-logloss:0.40970
# [557]#011train-logloss:0.36808#011validation-logloss:0.40971
# [558]#011train-logloss:0.36807#011validation-logloss:0.40967
# [559]#011train-logloss:0.36807#011validation-logloss:0.40968
# [560]#011train-logloss:0.36806#011validation-logloss:0.40971
# [561]#011train-logloss:0.36806#011validation-logloss:0.40971
# [562]#011train-logloss:0.36804#011validation-logloss:0.40968
# [563]#011train-logloss:0.36804#011validation-logloss:0.40973
# [564]#011train-logloss:0.36802#011validation-logloss:0.40970
# [565]#011train-logloss:0.36802#011validation-logloss:0.40972
# [566]#011train-logloss:0.36802#011validation-logloss:0.40971
# [567]#011train-logloss:0.36800#011validation-logloss:0.40971
# [568]#011train-logloss:0.36800#011validation-logloss:0.40972
# [569]#011train-logloss:0.36799#011validation-logloss:0.40972
# [570]#011train-logloss:0.36794#011validation-logloss:0.40974
# [571]#011train-logloss:0.36794#011validation-logloss:0.40974
# [572]#011train-logloss:0.36793#011validation-logloss:0.40975
# [573]#011train-logloss:0.36793#011validation-logloss:0.40978
# [574]#011train-logloss:0.36793#011validation-logloss:0.40980
# [575]#011train-logloss:0.36794#011validation-logloss:0.40979
# [576]#011train-logloss:0.36793#011validation-logloss:0.40977
# [577]#011train-logloss:0.36792#011validation-logloss:0.40979
# [578]#011train-logloss:0.36790#011validation-logloss:0.40978
# [579]#011train-logloss:0.36790#011validation-logloss:0.40979
# [580]#011train-logloss:0.36788#011validation-logloss:0.40978
# [581]#011train-logloss:0.36788#011validation-logloss:0.40976
# [582]#011train-logloss:0.36788#011validation-logloss:0.40978
# [583]#011train-logloss:0.36787#011validation-logloss:0.40975
# [584]#011train-logloss:0.36786#011validation-logloss:0.40977
# [585]#011train-logloss:0.36785#011validation-logloss:0.40975
# [586]#011train-logloss:0.36784#011validation-logloss:0.40979
# [587]#011train-logloss:0.36784#011validation-logloss:0.40978
# [588]#011train-logloss:0.36782#011validation-logloss:0.40983
# [589]#011train-logloss:0.36782#011validation-logloss:0.40982
# [590]#011train-logloss:0.36782#011validation-logloss:0.40981
# [591]#011train-logloss:0.36780#011validation-logloss:0.40981
# [592]#011train-logloss:0.36780#011validation-logloss:0.40979
# [593]#011train-logloss:0.36779#011validation-logloss:0.40977
# [594]#011train-logloss:0.36779#011validation-logloss:0.40975
# [595]#011train-logloss:0.36777#011validation-logloss:0.40975
# [596]#011train-logloss:0.36774#011validation-logloss:0.40976
# [597]#011train-logloss:0.36773#011validation-logloss:0.40979
# [598]#011train-logloss:0.36772#011validation-logloss:0.40978
# [599]#011train-logloss:0.36772#011validation-logloss:0.40978
# [600]#011train-logloss:0.36769#011validation-logloss:0.40979
# [601]#011train-logloss:0.36768#011validation-logloss:0.40976
# [602]#011train-logloss:0.36766#011validation-logloss:0.40980
# [603]#011train-logloss:0.36763#011validation-logloss:0.40982
# [604]#011train-logloss:0.36761#011validation-logloss:0.40984
# [605]#011train-logloss:0.36760#011validation-logloss:0.40983
# [606]#011train-logloss:0.36758#011validation-logloss:0.40985
# [607]#011train-logloss:0.36758#011validation-logloss:0.40985
# [608]#011train-logloss:0.36758#011validation-logloss:0.40985
# [609]#011train-logloss:0.36757#011validation-logloss:0.40987
# [610]#011train-logloss:0.36755#011validation-logloss:0.40987
# [611]#011train-logloss:0.36754#011validation-logloss:0.40991
# [612]#011train-logloss:0.36748#011validation-logloss:0.40989
# [613]#011train-logloss:0.36747#011validation-logloss:0.40988
# [614]#011train-logloss:0.36746#011validation-logloss:0.40989
# [615]#011train-logloss:0.36744#011validation-logloss:0.40992
# [616]#011train-logloss:0.36743#011validation-logloss:0.40993
# [617]#011train-logloss:0.36743#011validation-logloss:0.40991
# [618]#011train-logloss:0.36742#011validation-logloss:0.40993
# [619]#011train-logloss:0.36742#011validation-logloss:0.40994
# [620]#011train-logloss:0.36742#011validation-logloss:0.40993
# [621]#011train-logloss:0.36741#011validation-logloss:0.40994
# [622]#011train-logloss:0.36741#011validation-logloss:0.40993
# [623]#011train-logloss:0.36741#011validation-logloss:0.40993
# [624]#011train-logloss:0.36739#011validation-logloss:0.40991
# [625]#011train-logloss:0.36739#011validation-logloss:0.40990
# [626]#011train-logloss:0.36739#011validation-logloss:0.40989
# [627]#011train-logloss:0.36738#011validation-logloss:0.40993
# [628]#011train-logloss:0.36733#011validation-logloss:0.40994
# [629]#011train-logloss:0.36733#011validation-logloss:0.40996
# [630]#011train-logloss:0.36732#011validation-logloss:0.40998
# [631]#011train-logloss:0.36732#011validation-logloss:0.40999
# [632]#011train-logloss:0.36732#011validation-logloss:0.40998
# [633]#011train-logloss:0.36731#011validation-logloss:0.40999
# [634]#011train-logloss:0.36730#011validation-logloss:0.40997
# [635]#011train-logloss:0.36730#011validation-logloss:0.40998
# [636]#011train-logloss:0.36727#011validation-logloss:0.40999
# [637]#011train-logloss:0.36725#011validation-logloss:0.41002
# [638]#011train-logloss:0.36724#011validation-logloss:0.41000
# [639]#011train-logloss:0.36724#011validation-logloss:0.40999
# [640]#011train-logloss:0.36724#011validation-logloss:0.41002
# [641]#011train-logloss:0.36724#011validation-logloss:0.41001
# [642]#011train-logloss:0.36724#011validation-logloss:0.40999
# [643]#011train-logloss:0.36724#011validation-logloss:0.41000
# [644]#011train-logloss:0.36723#011validation-logloss:0.40996
# [645]#011train-logloss:0.36723#011validation-logloss:0.40993
# [646]#011train-logloss:0.36719#011validation-logloss:0.40994
# [647]#011train-logloss:0.36717#011validation-logloss:0.40994
# [648]#011train-logloss:0.36717#011validation-logloss:0.40993
# [649]#011train-logloss:0.36715#011validation-logloss:0.40996
# [650]#011train-logloss:0.36714#011validation-logloss:0.40995
# [651]#011train-logloss:0.36711#011validation-logloss:0.40997
# [652]#011train-logloss:0.36709#011validation-logloss:0.40999
# [653]#011train-logloss:0.36707#011validation-logloss:0.41001
# [654]#011train-logloss:0.36705#011validation-logloss:0.41004
# [655]#011train-logloss:0.36705#011validation-logloss:0.41005
# [656]#011train-logloss:0.36705#011validation-logloss:0.41007
# [657]#011train-logloss:0.36705#011validation-logloss:0.41009
# [658]#011train-logloss:0.36700#011validation-logloss:0.41012
# [659]#011train-logloss:0.36700#011validation-logloss:0.41011
# [660]#011train-logloss:0.36700#011validation-logloss:0.41011
# [661]#011train-logloss:0.36698#011validation-logloss:0.41009
# [662]#011train-logloss:0.36698#011validation-logloss:0.41009
# [663]#011train-logloss:0.36692#011validation-logloss:0.41013
# [664]#011train-logloss:0.36686#011validation-logloss:0.41014
# [665]#011train-logloss:0.36686#011validation-logloss:0.41014
# [666]#011train-logloss:0.36685#011validation-logloss:0.41013
# [667]#011train-logloss:0.36685#011validation-logloss:0.41013
# [668]#011train-logloss:0.36684#011validation-logloss:0.41014
# [669]#011train-logloss:0.36684#011validation-logloss:0.41014
# [670]#011train-logloss:0.36679#011validation-logloss:0.41018
# [671]#011train-logloss:0.36674#011validation-logloss:0.41017
# [672]#011train-logloss:0.36670#011validation-logloss:0.41019
# [673]#011train-logloss:0.36669#011validation-logloss:0.41019
# [674]#011train-logloss:0.36669#011validation-logloss:0.41019
# [675]#011train-logloss:0.36668#011validation-logloss:0.41017
# [676]#011train-logloss:0.36668#011validation-logloss:0.41017
# [677]#011train-logloss:0.36667#011validation-logloss:0.41016
# [678]#011train-logloss:0.36666#011validation-logloss:0.41015
# [679]#011train-logloss:0.36664#011validation-logloss:0.41020
# [680]#011train-logloss:0.36664#011validation-logloss:0.41021
# [681]#011train-logloss:0.36664#011validation-logloss:0.41021
# [682]#011train-logloss:0.36664#011validation-logloss:0.41021
# [683]#011train-logloss:0.36664#011validation-logloss:0.41019
# [684]#011train-logloss:0.36664#011validation-logloss:0.41018
# [685]#011train-logloss:0.36661#011validation-logloss:0.41018
# [686]#011train-logloss:0.36661#011validation-logloss:0.41019
# [687]#011train-logloss:0.36661#011validation-logloss:0.41021
# [688]#011train-logloss:0.36661#011validation-logloss:0.41021
# [689]#011train-logloss:0.36661#011validation-logloss:0.41019
# [690]#011train-logloss:0.36658#011validation-logloss:0.41018
# [691]#011train-logloss:0.36657#011validation-logloss:0.41016
# [692]#011train-logloss:0.36656#011validation-logloss:0.41019
# [693]#011train-logloss:0.36656#011validation-logloss:0.41017
# [694]#011train-logloss:0.36655#011validation-logloss:0.41019
# [695]#011train-logloss:0.36655#011validation-logloss:0.41017
# [696]#011train-logloss:0.36655#011validation-logloss:0.41019
# [697]#011train-logloss:0.36653#011validation-logloss:0.41019
# [698]#011train-logloss:0.36652#011validation-logloss:0.41021
# [699]#011train-logloss:0.36652#011validation-logloss:0.41022
# [700]#011train-logloss:0.36651#011validation-logloss:0.41025
# [701]#011train-logloss:0.36648#011validation-logloss:0.41024
# [702]#011train-logloss:0.36648#011validation-logloss:0.41024
# [703]#011train-logloss:0.36646#011validation-logloss:0.41024
# [704]#011train-logloss:0.36646#011validation-logloss:0.41025
# [705]#011train-logloss:0.36645#011validation-logloss:0.41026
# [706]#011train-logloss:0.36644#011validation-logloss:0.41025
# [707]#011train-logloss:0.36642#011validation-logloss:0.41023
# [708]#011train-logloss:0.36642#011validation-logloss:0.41025
# [709]#011train-logloss:0.36642#011validation-logloss:0.41027
# [710]#011train-logloss:0.36640#011validation-logloss:0.41026
# [711]#011train-logloss:0.36639#011validation-logloss:0.41023
# [712]#011train-logloss:0.36639#011validation-logloss:0.41019
# [713]#011train-logloss:0.36638#011validation-logloss:0.41019
# [714]#011train-logloss:0.36637#011validation-logloss:0.41019
# [715]#011train-logloss:0.36637#011validation-logloss:0.41021
# [716]#011train-logloss:0.36636#011validation-logloss:0.41020
# [717]#011train-logloss:0.36636#011validation-logloss:0.41021
# [718]#011train-logloss:0.36629#011validation-logloss:0.41026
# [719]#011train-logloss:0.36628#011validation-logloss:0.41027
# [720]#011train-logloss:0.36627#011validation-logloss:0.41025
# [721]#011train-logloss:0.36627#011validation-logloss:0.41024
# [722]#011train-logloss:0.36626#011validation-logloss:0.41024
# [723]#011train-logloss:0.36624#011validation-logloss:0.41027
# [724]#011train-logloss:0.36624#011validation-logloss:0.41026
# [725]#011train-logloss:0.36623#011validation-logloss:0.41025
# [726]#011train-logloss:0.36622#011validation-logloss:0.41026
# [727]#011train-logloss:0.36622#011validation-logloss:0.41026
# [728]#011train-logloss:0.36622#011validation-logloss:0.41028
# [729]#011train-logloss:0.36621#011validation-logloss:0.41030
# [730]#011train-logloss:0.36619#011validation-logloss:0.41033
# [731]#011train-logloss:0.36616#011validation-logloss:0.41035
# [732]#011train-logloss:0.36617#011validation-logloss:0.41036
# [733]#011train-logloss:0.36615#011validation-logloss:0.41034
# [734]#011train-logloss:0.36615#011validation-logloss:0.41032
# [735]#011train-logloss:0.36614#011validation-logloss:0.41033
# [736]#011train-logloss:0.36614#011validation-logloss:0.41035
# [737]#011train-logloss:0.36613#011validation-logloss:0.41033
# [738]#011train-logloss:0.36613#011validation-logloss:0.41031
# [739]#011train-logloss:0.36613#011validation-logloss:0.41031
# [740]#011train-logloss:0.36611#011validation-logloss:0.41034
# [741]#011train-logloss:0.36611#011validation-logloss:0.41034
# [742]#011train-logloss:0.36610#011validation-logloss:0.41031
# [743]#011train-logloss:0.36608#011validation-logloss:0.41029
# [744]#011train-logloss:0.36607#011validation-logloss:0.41033
# [745]#011train-logloss:0.36607#011validation-logloss:0.41032
# [746]#011train-logloss:0.36607#011validation-logloss:0.41029
# [747]#011train-logloss:0.36606#011validation-logloss:0.41034
# [748]#011train-logloss:0.36605#011validation-logloss:0.41033
# [749]#011train-logloss:0.36605#011validation-logloss:0.41033
# [750]#011train-logloss:0.36605#011validation-logloss:0.41036
# [751]#011train-logloss:0.36604#011validation-logloss:0.41037
# [752]#011train-logloss:0.36604#011validation-logloss:0.41036
# [753]#011train-logloss:0.36604#011validation-logloss:0.41035
# [754]#011train-logloss:0.36603#011validation-logloss:0.41031
# [755]#011train-logloss:0.36602#011validation-logloss:0.41036
# [756]#011train-logloss:0.36601#011validation-logloss:0.41036
# [757]#011train-logloss:0.36601#011validation-logloss:0.41036
# [758]#011train-logloss:0.36601#011validation-logloss:0.41033
# [759]#011train-logloss:0.36601#011validation-logloss:0.41032
# [760]#011train-logloss:0.36601#011validation-logloss:0.41034
# [761]#011train-logloss:0.36601#011validation-logloss:0.41033
# [762]#011train-logloss:0.36600#011validation-logloss:0.41033
# [763]#011train-logloss:0.36595#011validation-logloss:0.41035
# [764]#011train-logloss:0.36595#011validation-logloss:0.41035
# [765]#011train-logloss:0.36595#011validation-logloss:0.41036
# [766]#011train-logloss:0.36592#011validation-logloss:0.41035
# [767]#011train-logloss:0.36591#011validation-logloss:0.41038
# [768]#011train-logloss:0.36591#011validation-logloss:0.41037
# [769]#011train-logloss:0.36590#011validation-logloss:0.41038
# [770]#011train-logloss:0.36590#011validation-logloss:0.41042
# [771]#011train-logloss:0.36590#011validation-logloss:0.41038
# [772]#011train-logloss:0.36590#011validation-logloss:0.41041
# [773]#011train-logloss:0.36590#011validation-logloss:0.41038
# [774]#011train-logloss:0.36590#011validation-logloss:0.41036
# [775]#011train-logloss:0.36589#011validation-logloss:0.41035
# [776]#011train-logloss:0.36589#011validation-logloss:0.41038
# [777]#011train-logloss:0.36588#011validation-logloss:0.41038
# [778]#011train-logloss:0.36588#011validation-logloss:0.41036
# [779]#011train-logloss:0.36586#011validation-logloss:0.41038
# [780]#011train-logloss:0.36585#011validation-logloss:0.41037
# [781]#011train-logloss:0.36584#011validation-logloss:0.41034
# [782]#011train-logloss:0.36582#011validation-logloss:0.41034
# [783]#011train-logloss:0.36582#011validation-logloss:0.41032
#
# 2023-01-04 12:17:41 Uploading - Uploading generated training model[784]#011train-logloss:0.36582#011validation-logloss:0.41031
# [785]#011train-logloss:0.36582#011validation-logloss:0.41031
# [786]#011train-logloss:0.36581#011validation-logloss:0.41033
# [787]#011train-logloss:0.36581#011validation-logloss:0.41038
# [788]#011train-logloss:0.36581#011validation-logloss:0.41040
# [789]#011train-logloss:0.36581#011validation-logloss:0.41039
# [790]#011train-logloss:0.36580#011validation-logloss:0.41036
# [791]#011train-logloss:0.36580#011validation-logloss:0.41037
# [792]#011train-logloss:0.36579#011validation-logloss:0.41038
# [793]#011train-logloss:0.36579#011validation-logloss:0.41039
# [794]#011train-logloss:0.36577#011validation-logloss:0.41037
# [795]#011train-logloss:0.36576#011validation-logloss:0.41040
# [796]#011train-logloss:0.36574#011validation-logloss:0.41046
# [797]#011train-logloss:0.36573#011validation-logloss:0.41046
# [798]#011train-logloss:0.36573#011validation-logloss:0.41046
# [799]#011train-logloss:0.36573#011validation-logloss:0.41048
#
# 2023-01-04 12:17:52 Completed - Training job completed
# Training seconds: 92
# Billable seconds: 92

# %% [markdown]
# ### 推論データ準備
# 推論用データとして学習データと同様の加工を行い、説明変数のみからなる推論用データと正解データのデータを作成します。

# %%
# test_data = data_processing('cps_2021.csv')
test_data = data_processing('cps_2022.csv')

num_examples, num_columns = test_data.shape
print(
    f"The test dataset contains {num_examples} examples and {num_columns} columns.\n"
)

ground_truth_label, features = test_data.iloc[:, :1], test_data.iloc[:, 1:]

features.to_csv('testdata.csv', header=False, index=False)

dataset_type = "text/csv"
test_dataset = 'testdata.csv'
# Out:
# The test dataset contains 114158 examples and 14 columns.

# %% [markdown]
# ### 推論エンドポイント作成
# 作成したモデルを用いてエンドポイントをデプロイします。

# %%
model_url = xgb.model_data
print(f"Model file is stored in {model_url}")
# Out:
# Model file is stored in s3://sagemaker-ap-northeast-1-036661559124/sagemaker-xgboost-2023-01-04-12-14-14-700/output/model.tar.gz

# %%
model_name = f'xgb-{datetime.now():%Y-%m-%d-%H%M}'
print("Model name: ", model_name)
print("Endpoint name: ", endpoint_name)
# Out:
# Model name:  xgb-2023-01-04-1218
# Endpoint name:  bb-example-xgboost-classification-model-2023-01-04-12-11-59-829

# %%
image_uri = image_uris.retrieve("xgboost", region, "1.5-1")

print(f"XGBoost image uri: {image_uri}")
model = Model(
    role=role,
    name=model_name,
    image_uri=image_uri,
    model_data=model_url,
    sagemaker_session=sagemaker_session,
)

data_capture_config = DataCaptureConfig(
    enable_capture=True,
    sampling_percentage=100,
    destination_s3_uri=s3_capture_upload_path,
)

print(f"Deploying model {model_name} to endpoint {endpoint_name}")
model.deploy(
    initial_instance_count=endpoint_instance_count,
    instance_type=endpoint_instance_type,
    endpoint_name=endpoint_name,
    data_capture_config=data_capture_config,
)
# Out:
# XGBoost image uri: 354813040037.dkr.ecr.ap-northeast-1.amazonaws.com/sagemaker-xgboost:1.5-1
# Deploying model xgb-2023-01-04-1218 to endpoint bb-example-xgboost-classification-model-2023-01-04-12-11-59-829
# -----!

# %% [markdown]
# ### 推論
# 作成したエンドポイントを使用して推論を実行します。Feature Attributionでドリフトを検知したい場合はコメントアウトされているpayloadを使用してください。

# %%
print(f"Sending test traffic to the endpoint {endpoint_name}. \nPlease wait", end="")
test_dataset_size = 0  # record the number of rows in data we're sending for inference
with open(test_dataset, "r") as f:
    for row in f:
        if 400 < test_dataset_size and test_dataset_size < 450:
            payload = row.rstrip("\n")
            # 下記を有効にするとFeature Attributionのドリフトが検知できる
            # payload = '100,100,100,100,100,100,100,100,100,100,100,100,100'
            response = sagemaker_runtime_client.invoke_endpoint(
                EndpointName=endpoint_name,
                Body=payload,
                ContentType=dataset_type,
                InferenceId=str(test_dataset_size),
            )
            prediction = response["Body"].read()
            print(".", end="", flush=True)
            time.sleep(0.5)
        test_dataset_size += 1

print()
print("Done!")
# Out:
# Sending test traffic to the endpoint bb-example-xgboost-classification-model-2023-01-04-12-11-59-829.
# Please wait.................................................
# Done!

# %% [markdown]
# ### キャプチャデータの確認
# キャプチャされたデータを確認します。
#
# もし600秒では足りず、エラーになった場合は時間をおいて再度実行してみてください。
#
# こちらのコードはキャプチャデータの確認のみが目的のため、実行が完了していなくても、先に進むことができます。

# %%
print("Waiting 600 seconds for captures to show up", end="")
for _ in range(600):
    capture_files = sorted(S3Downloader.list(f"{s3_capture_upload_path}/{endpoint_name}"))
    if capture_files:
        break
    print(".", end="", flush=True)
    time.sleep(1)
print()
print("Found Capture Files:")
print("\n ".join(capture_files[-5:]))
# Out:
# Waiting 600 seconds for captures to show up.................................................
# Found Capture Files:
# s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/datacapture/bb-example-xgboost-classification-model-2023-01-04-12-11-59-829/AllTraffic/2023/01/04/12/21-01-974-079e84cc-98a0-41fa-842a-f18c59da9013.jsonl

# %%
capture_file = S3Downloader.read_file(capture_files[-1]).split("\n")[-10:-1]
print(capture_file[-1])
# Out:
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"77,0,44,0,1,2,0,-1,0,57,1,0,0","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"0.2509244382381439\n","encoding":"CSV"}},"eventMetadata":{"eventId":"a608eba5-9aef-4580-8dba-a2b35aa94324","inferenceId":"449","inferenceTime":"2023-01-04T12:21:26Z"},"eventVersion":"0"}

# %%
print(json.dumps(json.loads(capture_file[-1]), indent=2))
# Out:
# {
#   "captureData": {
#     "endpointInput": {
#       "observedContentType": "text/csv",
#       "mode": "INPUT",
#       "data": "77,0,44,0,1,2,0,-1,0,57,1,0,0",
#       "encoding": "CSV"
#     },
#     "endpointOutput": {
#       "observedContentType": "text/csv; charset=utf-8",
#       "mode": "OUTPUT",
#       "data": "0.2509244382381439\n",
#       "encoding": "CSV"
#     }
#   },
#   "eventMetadata": {
#     "eventId": "a608eba5-9aef-4580-8dba-a2b35aa94324",
#     "inferenceId": "449",
#     "inferenceTime": "2023-01-04T12:21:26Z"
#   },
#   "eventVersion": "0"
# }

# %% [markdown]
# ### 正解データのアップロード
# 正解データをアップロードします。正解データがない場合、バイアスのスケジュールジョブは失敗します。

# %%
# import random

def ground_truth_with_id(inference_id):
    # random.seed(inference_id)
    # rand = random.random()

    return {
        "groundTruthData": {
            # ランダムなデータを正解として用意する場合のサンプルコード
            # "data": "1" if rand < 0.7 else "0",
            "data": str(ground_truth_label.iat[inference_id,0]),
            "encoding": "CSV",
        },
        "eventMetadata": {
            "eventId": str(inference_id),
        },
        "eventVersion": "0",
    }


def upload_ground_truth(upload_time):
    records = [ground_truth_with_id(i) for i in range(test_dataset_size)]
    fake_records = [json.dumps(r) for r in records]
    data_to_upload = "\n".join(fake_records)
    target_s3_uri = f"{ground_truth_upload_path}/{upload_time:%Y/%m/%d/%H/%M%S}.jsonl"
    print(f"Uploading {len(fake_records)} records to", target_s3_uri)
    S3Uploader.upload_string_as_file_body(data_to_upload, target_s3_uri)

# %%
upload_ground_truth(datetime.now())
# Out:
# Uploading 114158 records to s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/ground_truth_data/2023-01-04-12-11-59/2023/01/04/12/2231.jsonl

# %% [markdown]
# ## ステップ1: モデルバイアス
# ### ベースライン作成
# ベースラインの作成には10分程度かかります。

# %%
model_bias_monitor = ModelBiasMonitor(
    role=role,
    sagemaker_session=sagemaker_session,
    max_runtime_in_seconds=1800,
)

# %%
model_bias_baselining_job_result_uri = f"{baseline_results_uri}/model_bias"
model_bias_data_config = DataConfig(
    s3_data_input_path=baseline_uri,
    s3_output_path=model_bias_baselining_job_result_uri,
    label=label_header,
    headers=all_headers,
    dataset_type=dataset_type,
)

# %%
model_bias_config = BiasConfig(
    label_values_or_threshold=[1], 
    facet_name='A_SEX',
    group_name='A_HGA'
)

# %%
model_predicted_label_config = ModelPredictedLabelConfig(
    probability_threshold=0.7,
)

# %%
model_config = ModelConfig(
    model_name=model_name,
    instance_count=endpoint_instance_count,
    instance_type=endpoint_instance_type,
    content_type=dataset_type,
    accept_type=dataset_type,
)

# %%
model_bias_monitor.suggest_baseline(
    model_config=model_config,
    data_config=model_bias_data_config,
    bias_config=model_bias_config,
    model_predicted_label_config=model_predicted_label_config,
)
print(f"ModelBiasMonitor baselining job: {model_bias_monitor.latest_baselining_job_name}")
# Out:
# Job Name:  baseline-suggestion-job-2023-01-04-12-22-36-206
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/baselining/baseline/baseline_with_header.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/baselining/model_bias/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/baselining/model_bias', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ModelBiasMonitor baselining job: baseline-suggestion-job-2023-01-04-12-22-36-206

# %%
model_bias_monitor.latest_baselining_job.wait(logs=False)
model_bias_constraints = model_bias_monitor.suggested_constraints()
print()
print(f"ModelBiasMonitor suggested constraints: {model_bias_constraints.file_s3_uri}")
print(S3Downloader.read_file(model_bias_constraints.file_s3_uri))
# Out:
# ...................................................................................................!
# ModelBiasMonitor suggested constraints: s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/baselining/model_bias/analysis.json
# {
#     "version": "1.0",
#     "post_training_bias_metrics": {
#         "label": "PTOTVAL_Over50000",
#         "facets": {
#             "A_SEX": [
#                 {
#                     "value_or_threshold": "1",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": 0.047995482778091514
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": -0.35173994883458676
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": -0.18103448275862066
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": 0.6393678160919543
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": -0.10960185448777915
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 2.586783988957902
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": -0.14732230458409923
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": -0.10581386566583206
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": 0.12215320910973085
#                         },
#                         {
#                             "name": "GE",
#                             "description": "Generalized Entropy (GE)",
#                             "value": 0.12748753989027944
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": -0.20676359546951556
#                         },
#                         {
#                             "name": "SD",
#                             "description": "Specificity Difference (SD)",
#                             "value": 0.0006634232640424509
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": 6.041666666666667
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "2",
#                     "metrics": [
#                         {
#                             "name": "AD",
#                             "description": "Accuracy Difference (AD)",
#                             "value": -0.047995482778091514
#                         },
#                         {
#                             "name": "CDDPL",
#                             "description": "Conditional Demographic Disparity in Predicted Labels (CDDPL)",
#                             "value": 0.46273994883458675
#                         },
#                         {
#                             "name": "DAR",
#                             "description": "Difference in Acceptance Rates (DAR)",
#                             "value": 0.18103448275862066
#                         },
#                         {
#                             "name": "DCA",
#                             "description": "Difference in Conditional Acceptance (DCA)",
#                             "value": -0.6393678160919543
#                         },
#                         {
#                             "name": "DCR",
#                             "description": "Difference in Conditional Rejection (DCR)",
#                             "value": 0.10960185448777915
#                         },
#                         {
#                             "name": "DI",
#                             "description": "Disparate Impact (DI)",
#                             "value": 0.3865804041886214
#                         },
#                         {
#                             "name": "DPPL",
#                             "description": "Difference in Positive Proportions in Predicted Labels (DPPL)",
#                             "value": 0.14732230458409923
#                         },
#                         {
#                             "name": "DRR",
#                             "description": "Difference in Rejection Rates (DRR)",
#                             "value": 0.10581386566583206
#                         },
#                         {
#                             "name": "FT",
#                             "description": "Flip Test (FT)",
#                             "value": -0.09671179883945841
#                         },
#                         {
#                             "name": "GE",
#                             "description": "Generalized Entropy (GE)",
#                             "value": 0.12748753989027944
#                         },
#                         {
#                             "name": "RD",
#                             "description": "Recall Difference (RD)",
#                             "value": 0.20676359546951556
#                         },
#                         {
#                             "name": "SD",
#                             "description": "Specificity Difference (SD)",
#                             "value": -0.0006634232640424509
#                         },
#                         {
#                             "name": "TE",
#                             "description": "Treatment Equality (TE)",
#                             "value": -6.041666666666667
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     },
#     "pre_training_bias_metrics": {
#         "label": "PTOTVAL_Over50000",
#         "facets": {
#             "A_SEX": [
#                 {
#                     "value_or_threshold": "1",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": -0.27982989438014333
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": 0.034
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": -0.2086131568092715
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.024821569781261953
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.09503394708171636
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.2086131568092715
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.29502355564913696
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.2086131568092715
#                         }
#                     ]
#                 },
#                 {
#                     "value_or_threshold": "2",
#                     "metrics": [
#                         {
#                             "name": "CDDL",
#                             "description": "Conditional Demographic Disparity in Labels (CDDL)",
#                             "value": 0.2918298943801434
#                         },
#                         {
#                             "name": "CI",
#                             "description": "Class Imbalance (CI)",
#                             "value": -0.034
#                         },
#                         {
#                             "name": "DPL",
#                             "description": "Difference in Positive Proportions in Labels (DPL)",
#                             "value": 0.2086131568092715
#                         },
#                         {
#                             "name": "JS",
#                             "description": "Jensen-Shannon Divergence (JS)",
#                             "value": 0.024821569781261953
#                         },
#                         {
#                             "name": "KL",
#                             "description": "Kullback-Liebler Divergence (KL)",
#                             "value": 0.1061385749752419
#                         },
#                         {
#                             "name": "KS",
#                             "description": "Kolmogorov-Smirnov Distance (KS)",
#                             "value": 0.2086131568092715
#                         },
#                         {
#                             "name": "LP",
#                             "description": "L-p Norm (LP)",
#                             "value": 0.29502355564913696
#                         },
#                         {
#                             "name": "TVD",
#                             "description": "Total Variation Distance (TVD)",
#                             "value": 0.2086131568092715
#                         }
#                     ]
#                 }
#             ]
#         },
#         "label_value_or_threshold": "1"
#     }
# }

# %% [markdown]
# ### スケジュールジョブ作成

# %%
model_bias_analysis_config = None
if not model_bias_monitor.latest_baselining_job:
    model_bias_analysis_config = BiasAnalysisConfig(
        model_bias_config,
        headers=all_headers,
        label=label_header,
    )
model_bias_monitor.create_monitoring_schedule(
    analysis_config=model_bias_analysis_config,
    output_s3_uri=s3_report_path,
    endpoint_input=EndpointInput(
        endpoint_name=endpoint_name,
        destination="/opt/ml/processing/input/endpoint",
        start_time_offset="-PT1H",
        end_time_offset="-PT0H",
        probability_threshold_attribute=0.7,
    ),
    ground_truth_input=ground_truth_upload_path,
    schedule_cron_expression=schedule_expression,
    enable_cloudwatch_metrics=True,
)
print(f"Model bias monitoring schedule: {model_bias_monitor.monitoring_schedule_name}")
# Out:
# Model bias monitoring schedule: monitoring-schedule-2023-01-04-12-30-54-730

# %% [markdown]
# ## ステップ2: Feature Attribution
# ### ベースライン作成
# ベースラインの作成には10分程度かかります。

# %%
model_explainability_monitor = ModelExplainabilityMonitor(
    role=role,
    sagemaker_session=sagemaker_session,
    max_runtime_in_seconds=1800,
)

# %%
model_explainability_baselining_job_result_uri = f"{baseline_results_uri}/model_explainability"
model_explainability_data_config = DataConfig(
    s3_data_input_path=baseline_uri,
    s3_output_path=model_explainability_baselining_job_result_uri,
    label=label_header,
    headers=all_headers,
    dataset_type=dataset_type,
)

# %%
baseline_dataframe = pd.read_csv(baseline_uri).drop(label_header, axis=1)
shap_baseline = [list(baseline_dataframe.mean())]

shap_config = SHAPConfig(
    baseline=shap_baseline,
    num_samples=100,
    agg_method="mean_abs",
    save_local_shap_values=True,
)

# %%
model_explainability_monitor.suggest_baseline(
    data_config=model_explainability_data_config,
    model_config=model_config,
    explainability_config=shap_config,
)
print(
    f"ModelExplainabilityMonitor baselining job: {model_explainability_monitor.latest_baselining_job_name}"
)
# Out:
# Job Name:  baseline-suggestion-job-2023-01-04-12-30-55-986
# Inputs:  [{'InputName': 'dataset', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/baselining/baseline/baseline_with_header.csv', 'LocalPath': '/opt/ml/processing/input/data', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'analysis_config', 'AppManaged': False, 'S3Input': {'S3Uri': 's3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/baselining/model_explainability/analysis_config.json', 'LocalPath': '/opt/ml/processing/input/config', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'analysis_result', 'AppManaged': False, 'S3Output': {'S3Uri': 's3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/baselining/model_explainability', 'LocalPath': '/opt/ml/processing/output', 'S3UploadMode': 'EndOfJob'}}]
# ModelExplainabilityMonitor baselining job: baseline-suggestion-job-2023-01-04-12-30-55-986

# %%
model_explainability_monitor.latest_baselining_job.wait(logs=False)
model_explainability_constraints = model_explainability_monitor.suggested_constraints()
print()
print(
    f"ModelExplainabilityMonitor suggested constraints: {model_explainability_constraints.file_s3_uri}"
)
print(S3Downloader.read_file(model_explainability_constraints.file_s3_uri))
# Out:
# .........................................................................................................!
# ModelExplainabilityMonitor suggested constraints: s3://sagemaker-ap-northeast-1-036661559124/sagemaker/blackbelt-part3-sample/baselining/model_explainability/analysis.json
# {
#     "version": "1.0",
#     "explanations": {
#         "kernel_shap": {
#             "label0": {
#                 "global_shap_values": {
#                     "A_AGE": 0.03900713880041894,
#                     "A_FTLF": 0.009864065651959351,
#                     "A_HGA": 0.08227859137445104,
#                     "A_HSCOL": 0.006078339682850803,
#                     "A_MARITL": 0.020923815390634877,
#                     "A_SEX": 0.0464811787751795,
#                     "A_UNMEM": 0.00656392329159415,
#                     "A_USLHRS": 0.09165896714888844,
#                     "NOEMP": 0.029412844725952524,
#                     "PENATVTY": 0.03568894808061845,
#                     "PRCITSHP": 0.008444406567974315,
#                     "SEOTR": 0.008066975367524291,
#                     "WKSWORK": 0.10033051463598301
#                 },
#                 "expected_value": 0.05636756867170334
#             }
#         }
#     }
# }

# %% [markdown]
# ### スケジュールジョブ作成

# %%
model_explainability_analysis_config = None
if not model_explainability_monitor.latest_baselining_job:
    headers_without_label_header = copy.deepcopy(all_headers)
    headers_without_label_header.remove(label_header)
    model_explainability_analysis_config = ExplainabilityAnalysisConfig(
        explainability_config=shap_config,
        model_config=model_config,
        headers=headers_without_label_header,
    )
model_explainability_monitor.create_monitoring_schedule(
    analysis_config = model_explainability_analysis_config,
    output_s3_uri=s3_report_path,
    endpoint_input=endpoint_name,
    schedule_cron_expression=schedule_expression,
    enable_cloudwatch_metrics=True,
)

# %% [markdown]
# ## ステップ3: リソース削除

# %%
model_bias_monitor.delete_monitoring_schedule()
# Out:
# Deleting Monitoring Schedule with name: monitoring-schedule-2023-01-04-12-30-54-730

# %%
model_explainability_monitor.delete_monitoring_schedule()
# Out:
# Deleting Monitoring Schedule with name: monitoring-schedule-2023-01-04-12-39-44-618

# %%
from sagemaker.predictor import Predictor

predictor = Predictor(endpoint_name, sagemaker_session=sagemaker_session)
predictor.delete_endpoint(delete_endpoint_config=False)

# %%
model.delete_model()
