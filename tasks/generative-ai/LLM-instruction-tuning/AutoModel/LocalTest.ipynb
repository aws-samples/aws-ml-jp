# %% [markdown]
# # Local Test
#
# This is a notebook to test scripts locally for faster experimenting using local cache and reduced launch time.

# %%
# %cd scripts/code

# %%
# !pip install -r requirements.txt
# !pip install sagemaker-training

# %%
from sagemaker_training.mapping import to_cmd_args

# %%
hyperparameters={
    'base_model':'cyberagent/open-calm-7b',
    'load_in_8bit': True,
    # 'load_in_4bit': True,
    'pad_token_id': 1,
    'data_path': '/opt/ml/input/data/train/databricks-dolly-15k-ja.json',
    'num_epochs': 1, # default 3
    'cutoff_len': 512,
    'group_by_length': False,
    'output_dir': '/opt/ml/model',
    'lora_target_modules': '[query_key_value]',
    'lora_r': 8,
    'batch_size': 32,
    'micro_batch_size': 4,
    'prompt_template_name': 'alpaca',
}

## Override hyperparameters for local testing
hyperparameters['data_path'] = "../../data/databricks-dolly-15k-ja.json"

## Convert to command line args
args = ' '.join(to_cmd_args(hyperparameters))
print(args)

# %%
# !python finetune.py {args}
